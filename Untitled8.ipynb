# %%
import pandas as pd
import numpy as np
from numpy import loadtxt
import os
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense,Dropout,MaxPooling2D,Conv2D,Flatten,Input,Conv2DTranspose,UpSampling2D,add
from tensorflow.keras.applications import VGG16
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import load_model
import pickle
from PIL import Image
from tensorflow.keras.models import load_model
from keras.preprocessing.image import img_to_array

# %%
  dir='/content/drive/MyDrive/Data'

# %%
high_res_images = []
low_res_images = []
SIZE=160
for dirname, _, filenames in os.walk(dir):
      for filename in filenames:
        print(os.path.join(dirname, filename))
        img = cv2.imread(os.path.join(dirname, filename))
        img = cv2.resize(img, (SIZE, SIZE))
        img = img.astype('float32') / 255.0
        low_res_images.append(img_to_array(img))
        
for dirname, _, filenames in os.walk(dir):      
      for filename in filenames:        
        print(os.path.join(dirname, filename))
        img = cv2.imread(os.path.join(dirname, filename))
        img = cv2.resize(img, (SIZE, SIZE))
        img = img.astype('float32') / 255.0
        high_res_images.append(img_to_array(img))
# Out:
# /content/drive/MyDrive/Data/HR/12.png
# /content/drive/MyDrive/Data/HR/11.png
# /content/drive/MyDrive/Data/HR/1.png
# /content/drive/MyDrive/Data/HR/10.png
# /content/drive/MyDrive/Data/HR/0.png
# /content/drive/MyDrive/Data/HR/13.png
# /content/drive/MyDrive/Data/HR/15.png
# /content/drive/MyDrive/Data/HR/14.png
# /content/drive/MyDrive/Data/HR/16.png
# /content/drive/MyDrive/Data/HR/18.png
# /content/drive/MyDrive/Data/HR/17.png
# /content/drive/MyDrive/Data/HR/19.png
# /content/drive/MyDrive/Data/HR/22.png
# /content/drive/MyDrive/Data/HR/21.png
# /content/drive/MyDrive/Data/HR/2.png
# /content/drive/MyDrive/Data/HR/26.png
# /content/drive/MyDrive/Data/HR/25.png
# /content/drive/MyDrive/Data/HR/23.png
# /content/drive/MyDrive/Data/HR/20.png
# /content/drive/MyDrive/Data/HR/24.png
# /content/drive/MyDrive/Data/HR/32.png
# /content/drive/MyDrive/Data/HR/27.png
# /content/drive/MyDrive/Data/HR/28.png
# /content/drive/MyDrive/Data/HR/29.png
# /content/drive/MyDrive/Data/HR/31.png
# /content/drive/MyDrive/Data/HR/30.png
# /content/drive/MyDrive/Data/HR/3.png
# /content/drive/MyDrive/Data/HR/33.png
# /content/drive/MyDrive/Data/HR/36.png
# /content/drive/MyDrive/Data/HR/34.png
# /content/drive/MyDrive/Data/HR/35.png
# /content/drive/MyDrive/Data/HR/37.png
# /content/drive/MyDrive/Data/HR/4.png
# /content/drive/MyDrive/Data/HR/39.png
# /content/drive/MyDrive/Data/HR/38.png
# /content/drive/MyDrive/Data/HR/43.png
# /content/drive/MyDrive/Data/HR/40.png
# /content/drive/MyDrive/Data/HR/46.png
# /content/drive/MyDrive/Data/HR/41.png
# /content/drive/MyDrive/Data/HR/42.png
# /content/drive/MyDrive/Data/HR/45.png
# /content/drive/MyDrive/Data/HR/44.png
# /content/drive/MyDrive/Data/HR/48.png
# /content/drive/MyDrive/Data/HR/47.png
# /content/drive/MyDrive/Data/HR/54.png
# /content/drive/MyDrive/Data/HR/55.png
# /content/drive/MyDrive/Data/HR/53.png
# /content/drive/MyDrive/Data/HR/51.png
# /content/drive/MyDrive/Data/LR/39.png
# /content/drive/MyDrive/Data/LR/37.png
# /content/drive/MyDrive/Data/LR/28.png
# /content/drive/MyDrive/Data/LR/34.png
# /content/drive/MyDrive/Data/LR/36.png
# /content/drive/MyDrive/Data/LR/42.png
# /content/drive/MyDrive/Data/LR/31.png
# /content/drive/MyDrive/Data/LR/33.png
# /content/drive/MyDrive/Data/LR/38.png
# /content/drive/MyDrive/Data/LR/41.png
# /content/drive/MyDrive/Data/LR/35.png
# /content/drive/MyDrive/Data/LR/3.png
# /content/drive/MyDrive/Data/LR/30.png
# /content/drive/MyDrive/Data/LR/4.png
# /content/drive/MyDrive/Data/LR/25.png
# /content/drive/MyDrive/Data/LR/48.png
# /content/drive/MyDrive/Data/LR/50.png
# /content/drive/MyDrive/Data/LR/45.png
# /content/drive/MyDrive/Data/LR/47.png
# /content/drive/MyDrive/Data/LR/44.png
# /content/drive/MyDrive/Data/LR/46.png
# /content/drive/MyDrive/Data/LR/5.png
# /content/drive/MyDrive/Data/LR/49.png
# /content/drive/MyDrive/Data/LR/55.png
# /content/drive/MyDrive/Data/LR/58.png
# /content/drive/MyDrive/Data/LR/66.png
# /content/drive/MyDrive/Data/LR/69.png
# /content/drive/MyDrive/Data/LR/68.png
# /content/drive/MyDrive/Data/LR/63.png
# /content/drive/MyDrive/Data/LR/60.png
# /content/drive/MyDrive/Data/LR/54.png
# /content/drive/MyDrive/Data/LR/59.png
# /content/drive/MyDrive/Data/LR/61.png
# /content/drive/MyDrive/Data/LR/6.png
# /content/drive/MyDrive/Data/LR/56.png
# /content/drive/MyDrive/Data/LR/64.png
# /content/drive/MyDrive/Data/LR/51.png
# /content/drive/MyDrive/Data/LR/53.png
# /content/drive/MyDrive/Data/LR/65.png
# /content/drive/MyDrive/Data/LR/52.png
# /content/drive/MyDrive/Data/LR/71.png
# /content/drive/MyDrive/Data/LR/57.png
# /content/drive/MyDrive/Data/LR/7.png
# /content/drive/MyDrive/Data/LR/70.png
# /content/drive/MyDrive/Data/LR/62.png
# /content/drive/MyDrive/Data/LR/67.png
# /content/drive/MyDrive/Data/LR/77.png
# /content/drive/MyDrive/Data/LR/76.png
# /content/drive/MyDrive/Data/LR/75.png
# /content/drive/MyDrive/Data/LR/74.png
# /content/drive/MyDrive/Data/LR/80.png
# /content/drive/MyDrive/Data/LR/8.png
# /content/drive/MyDrive/Data/LR/72.png
# /content/drive/MyDrive/Data/LR/78.png
# /content/drive/MyDrive/Data/LR/79.png
# /content/drive/MyDrive/Data/LR/73.png
# /content/drive/MyDrive/Data/LR/99.png
# /content/drive/MyDrive/Data/LR/85.png
# /content/drive/MyDrive/Data/LR/84.png
# /content/drive/MyDrive/Data/LR/90.png
# /content/drive/MyDrive/Data/LR/82.png
# /content/drive/MyDrive/Data/LR/98.png
# /content/drive/MyDrive/Data/LR/94.png
# /content/drive/MyDrive/Data/LR/97.png
# /content/drive/MyDrive/Data/LR/92.png
# /content/drive/MyDrive/Data/LR/83.png
# /content/drive/MyDrive/Data/LR/96.png
# /content/drive/MyDrive/Data/LR/87.png
# /content/drive/MyDrive/Data/LR/91.png
# /content/drive/MyDrive/Data/LR/88.png
# /content/drive/MyDrive/Data/LR/89.png
# /content/drive/MyDrive/Data/LR/93.png
# /content/drive/MyDrive/Data/LR/81.png
# /content/drive/MyDrive/Data/LR/95.png
# /content/drive/MyDrive/Data/LR/86.png
# /content/drive/MyDrive/Data/LR/9.png

# %%
train_high_image = high_res_images[:90]
train_low_image = low_res_images[:90]
train_high_image = np.reshape(train_high_image,(len(train_high_image),SIZE,SIZE,3))
train_low_image = np.reshape(train_low_image,(len(train_low_image),SIZE,SIZE,3))

test_high_image = high_res_images[90:]
test_low_image = low_res_images[90:]
test_high_image= np.reshape(test_high_image,(len(test_high_image),SIZE,SIZE,3))
test_low_image = np.reshape(test_low_image,(len(test_low_image),SIZE,SIZE,3))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
plt.figure(figsize=(10,10))
ax1.imshow(train_high_image[24])
ax1.title.set_text("low-res image ")
ax2.imshow(train_high_image[24])
ax2.title.set_text("high-res image ")

# %%
from tensorflow.python.keras.layers import Input, Dense
def down(filters , kernel_size, apply_batch_normalization = True):
    downsample = tf.keras.models.Sequential()
    downsample.add(layers.Conv2D(filters,kernel_size,padding = 'same', strides = 2))
    if apply_batch_normalization:
        downsample.add(layers.BatchNormalization())
    downsample.add(tf.keras.layers.LeakyReLU())
    return downsample


def up(filters, kernel_size, dropout = False):
    upsample = tf.keras.models.Sequential()
    upsample.add(layers.Conv2DTranspose(filters, kernel_size,padding = 'same', strides = 2))
    if dropout:
        upsample.dropout(0.2)
    upsample.add(tf.keras.layers.LeakyReLU())
    return upsample

def model():
    inputs = layers.Input(shape= [SIZE,SIZE,3])
    d1 = down(128,(3,3),False)(inputs)
    d2 = down(128,(3,3),False)(d1)
    d3 = down(256,(3,3),True)(d2)
    d4 = down(512,(3,3),True)(d3)
    
    d5 = down(512,(3,3),True)(d4)
    #upsampling
    u1 = up(512,(3,3),False)(d5)
    u1 = layers.concatenate([u1,d4])
    u2 = up(256,(3,3),False)(u1)
    u2 = layers.concatenate([u2,d3])
    u3 = up(128,(3,3),False)(u2)
    u3 = layers.concatenate([u3,d2])
    u4 = up(128,(3,3),False)(u3)
    u4 = layers.concatenate([u4,d1])
    u5 = up(3,(3,3),False)(u4)
    u5 = layers.concatenate([u5,inputs])
    output = layers.Conv2D(3,(2,2),strides = 1, padding = 'same')(u5)
    return tf.keras.Model(inputs=inputs, outputs=output)

model = model()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# sequential_8 (Sequential)       (None, 80, 80, 128)  3584        input_7[0][0]
# __________________________________________________________________________________________________
# sequential_9 (Sequential)       (None, 40, 40, 128)  147584      sequential_8[0][0]
# __________________________________________________________________________________________________
# sequential_10 (Sequential)      (None, 20, 20, 256)  296192      sequential_9[0][0]
# __________________________________________________________________________________________________
# sequential_11 (Sequential)      (None, 10, 10, 512)  1182208     sequential_10[0][0]
# __________________________________________________________________________________________________
# sequential_12 (Sequential)      (None, 5, 5, 512)    2361856     sequential_11[0][0]
# __________________________________________________________________________________________________
# sequential_13 (Sequential)      (None, 10, 10, 512)  2359808     sequential_12[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 10, 1024) 0           sequential_13[0][0]
#                                                                  sequential_11[0][0]
# __________________________________________________________________________________________________
# sequential_14 (Sequential)      (None, 20, 20, 256)  2359552     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 20, 512)  0           sequential_14[0][0]
#                                                                  sequential_10[0][0]
# __________________________________________________________________________________________________
# sequential_15 (Sequential)      (None, 40, 40, 128)  589952      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 40, 40, 256)  0           sequential_15[0][0]
#                                                                  sequential_9[0][0]
# __________________________________________________________________________________________________
# sequential_16 (Sequential)      (None, 80, 80, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80, 80, 256)  0           sequential_16[0][0]
#                                                                  sequential_8[0][0]
# __________________________________________________________________________________________________
# sequential_17 (Sequential)      (None, 160, 160, 3)  6915        concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 6)  0           sequential_17[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 160, 160, 3)  75          concatenate_4[0][0]
# ==================================================================================================
# Total params: 9,602,766
# Trainable params: 9,600,206
# Non-trainable params: 2,560
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = 'mean_absolute_error',
              metrics = ['acc'])

# %%
model.fit(train_low_image, train_high_image, 
          epochs = 25,
          batch_size = 32,
          verbose = 1,
          shuffle = True)
# Out:
# Epoch 1/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0495 - acc: 0.6383
# Epoch 2/25
# 3/3 [==============================] - 19s 6s/step - loss: 0.0466 - acc: 0.6650
# Epoch 3/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0450 - acc: 0.6636
# Epoch 4/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0442 - acc: 0.6561
# Epoch 5/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0428 - acc: 0.6714
# Epoch 6/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0418 - acc: 0.6782
# Epoch 7/25
# 3/3 [==============================] - 20s 7s/step - loss: 0.0410 - acc: 0.6880
# Epoch 8/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0402 - acc: 0.6851
# Epoch 9/25
# 3/3 [==============================] - 20s 7s/step - loss: 0.0396 - acc: 0.6915
# Epoch 10/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0395 - acc: 0.6930
# Epoch 11/25
# 3/3 [==============================] - 20s 7s/step - loss: 0.0387 - acc: 0.7040
# Epoch 12/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0383 - acc: 0.7024
# Epoch 13/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0378 - acc: 0.7002
# Epoch 14/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0374 - acc: 0.7047
# Epoch 15/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0369 - acc: 0.7095
# Epoch 16/25
# 3/3 [==============================] - 19s 6s/step - loss: 0.0367 - acc: 0.7087
# Epoch 17/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0369 - acc: 0.7116
# Epoch 18/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0368 - acc: 0.7078
# Epoch 19/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0364 - acc: 0.7065
# Epoch 20/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0361 - acc: 0.7118
# Epoch 21/25
# 3/3 [==============================] - 20s 7s/step - loss: 0.0365 - acc: 0.7100
# Epoch 22/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0356 - acc: 0.7115
# Epoch 23/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0355 - acc: 0.7215
# Epoch 24/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0355 - acc: 0.7094
# Epoch 25/25
# 3/3 [==============================] - 20s 6s/step - loss: 0.0351 - acc: 0.7158

# %%
def plot_images(high,low,predicted):
    plt.figure(figsize=(15,15))
    plt.subplot(1,3,1)
    plt.title('High Image')
    plt.imshow(high)
    plt.subplot(1,3,2)
    plt.title('Low Image ')
    plt.imshow(low)
    plt.subplot(1,3,3)
    plt.title('Predicted Image ')
    plt.imshow(predicted)
    
    plt.show()

for i in range(1,10):
    predicted = np.clip(model.predict(test_low_image[i].reshape(1,SIZE, SIZE,3)),0.0,1.0).reshape(SIZE, SIZE,3)
    plot_images(test_high_image[i],test_low_image[i],predicted)
    plt.savefig('OUTPUT')
